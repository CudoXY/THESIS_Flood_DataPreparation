# %%
import numpy as np
import pandas as pd
import os

from geopy.geocoders import Nominatim

# %% [markdown]
# # Define Constants

# %%
# Column names
COL_HEIGHT = 'flood_height'
COL_DATETIME = 'flood_time'
COL_LAT = 'lat'
COL_LNG = 'lng'

COL_IMGURL = 'image_url'
COL_DETAILS = 'details'

COL_LOCATION = 'location'

# File paths
FLOOD_2015_PATH = 'D:\\Gelo103097\\DLSU\\THESIS\\data\\Sliced Flood\\2015\\'
FLOOD_2015_COMPILED_PATH = 'flood_compiled_2015.csv'

# %% [markdown]
# # Compile Flood Data

# %% [markdown]
# ## Get all files in directory

# %%
file_list = []
file_list_krig = []

for file in os.listdir(FLOOD_2015_PATH):
    if not file.endswith(".csv"):
        continue
    
    if file.startswith('Table_'):
        file_list_krig.append(os.path.join(FLOOD_2015_PATH, file))
    else:
        file_list.append(os.path.join(FLOOD_2015_PATH, file))
        
file_list
# Out:
# ['D:\\Gelo103097\\DLSU\\THESIS\\data\\Sliced Flood\\2015\\Apr 27, 2015 0200 PM.csv',
#  'D:\\Gelo103097\\DLSU\\THESIS\\data\\Sliced Flood\\2015\\Aug 09, 2015 0240 PM.csv',
#  'D:\\Gelo103097\\DLSU\\THESIS\\data\\Sliced Flood\\2015\\Aug 17, 2015 0900 PM.csv',
#  'D:\\Gelo103097\\DLSU\\THESIS\\data\\Sliced Flood\\2015\\Aug 21, 2015 0430 PM.csv',
#  'D:\\Gelo103097\\DLSU\\THESIS\\data\\Sliced Flood\\2015\\Aug 21, 2015 0440 PM.csv',
#  'D:\\Gelo103097\\DLSU\\THESIS\\data\\Sliced Flood\\2015\\Aug 21, 2015 0500 PM.csv',
#  'D:\\Gelo103097\\DLSU\\THESIS\\data\\Sliced Flood\\2015\\Aug 23, 2015 0500 PM.csv',
#  'D:\\Gelo103097\\DLSU\\THESIS\\data\\Sliced Flood\\2015\\Aug 24, 2015 1000 PM.csv',
#  'D:\\Gelo103097\\DLSU\\THESIS\\data\\Sliced Flood\\2015\\Feb 13, 2015 0900 PM.csv',
#  'D:\\Gelo103097\\DLSU\\THESIS\\data\\Sliced Flood\\2015\\Jul 05, 2015 0400 PM.csv',
#  'D:\\Gelo103097\\DLSU\\THESIS\\data\\Sliced Flood\\2015\\Jul 09, 2015 0240 PM.csv',
#  'D:\\Gelo103097\\DLSU\\THESIS\\data\\Sliced Flood\\2015\\Jul 09, 2015 0800 PM.csv',
#  'D:\\Gelo103097\\DLSU\\THESIS\\data\\Sliced Flood\\2015\\Jul 12, 2015 1100 AM.csv',
#  'D:\\Gelo103097\\DLSU\\THESIS\\data\\Sliced Flood\\2015\\Jul 29, 2015 0300 PM.csv',
#  'D:\\Gelo103097\\DLSU\\THESIS\\data\\Sliced Flood\\2015\\Jun 02, 2015 1200 PM.csv',
#  'D:\\Gelo103097\\DLSU\\THESIS\\data\\Sliced Flood\\2015\\Jun 16, 2015 0300 AM.csv',
#  'D:\\Gelo103097\\DLSU\\THESIS\\data\\Sliced Flood\\2015\\May 05, 2015 1000 AM.csv',
#  'D:\\Gelo103097\\DLSU\\THESIS\\data\\Sliced Flood\\2015\\Nov 05, 2015 0200 AM.csv',
#  'D:\\Gelo103097\\DLSU\\THESIS\\data\\Sliced Flood\\2015\\Nov 05, 2015 0215 AM.csv',
#  'D:\\Gelo103097\\DLSU\\THESIS\\data\\Sliced Flood\\2015\\Nov 24, 2015 0600 PM.csv',
#  'D:\\Gelo103097\\DLSU\\THESIS\\data\\Sliced Flood\\2015\\Oct 09, 2015 0300 AM.csv',
#  'D:\\Gelo103097\\DLSU\\THESIS\\data\\Sliced Flood\\2015\\Oct 11, 2015 0200 PM.csv',
#  'D:\\Gelo103097\\DLSU\\THESIS\\data\\Sliced Flood\\2015\\Oct 11, 2015 0900 PM.csv',
#  'D:\\Gelo103097\\DLSU\\THESIS\\data\\Sliced Flood\\2015\\Oct 18, 2015 0700 AM.csv',
#  'D:\\Gelo103097\\DLSU\\THESIS\\data\\Sliced Flood\\2015\\Oct 18, 2015 1100 AM.csv',
#  'D:\\Gelo103097\\DLSU\\THESIS\\data\\Sliced Flood\\2015\\Oct 19, 2015 0300 PM.csv',
#  'D:\\Gelo103097\\DLSU\\THESIS\\data\\Sliced Flood\\2015\\Oct 19, 2015 1200 PM.csv',
#  'D:\\Gelo103097\\DLSU\\THESIS\\data\\Sliced Flood\\2015\\Oct 20, 2015 1200 PM.csv',
#  'D:\\Gelo103097\\DLSU\\THESIS\\data\\Sliced Flood\\2015\\Oct 22, 2015 1200 PM.csv',
#  'D:\\Gelo103097\\DLSU\\THESIS\\data\\Sliced Flood\\2015\\Sep 08, 2015 0100 PM.csv',
#  'D:\\Gelo103097\\DLSU\\THESIS\\data\\Sliced Flood\\2015\\Sep 08, 2015 0900 PM.csv',
#  'D:\\Gelo103097\\DLSU\\THESIS\\data\\Sliced Flood\\2015\\Sep 08, 2015 1100 PM.csv',
#  'D:\\Gelo103097\\DLSU\\THESIS\\data\\Sliced Flood\\2015\\Sep 09, 2015 0500 PM.csv',
#  'D:\\Gelo103097\\DLSU\\THESIS\\data\\Sliced Flood\\2015\\Sep 22, 2015 0900 PM.csv',
#  'D:\\Gelo103097\\DLSU\\THESIS\\data\\Sliced Flood\\2015\\Sep 30, 2015 1100 AM.csv']

# %% [markdown]
# ## Compile no kriging data

# %%
# Merge flood CSVs to one list
temp_list = []
for file_path in file_list:
    df = pd.read_csv(file_path, skipinitialspace=True)
    
    temp_list.append(df)
    
df_compiled = pd.concat(temp_list)

# Remove unused columns
df_compiled.drop([COL_IMGURL, COL_DETAILS], axis=1,  inplace=True)

len(df_compiled)
# Out:
# 65

# %% [markdown]
# ## Compile kriging data

# %%
# Merge flood CSVs to one list
temp_list = []

for file_path in file_list_krig:
    df = pd.read_csv(file_path, skipinitialspace=True)
    
    # Remove last column
    df = df.iloc[:, :-1]
    
    # Add datetime as second column
    datetime = file_path.rsplit('\\', 1)[1][:-4][6:]
    df.insert(loc=1, column=COL_DATETIME, value=datetime)
    
    # Update column names
    df.columns = df_compiled.columns
    
    temp_list.append(df)
    
# df_compiled = pd.DataFrame()    
df_compiled = df_compiled.append(temp_list, ignore_index=True)

len(df_compiled)
# Out:
# 430028

# %%
# Convert flood_time to datetime
df_compiled[COL_DATETIME] = pd.to_datetime(df_compiled[COL_DATETIME])

# Sort by flood_time
df_compiled.sort_values(by=COL_DATETIME, inplace=True)

df_compiled
# Out:
#         flood_height          flood_time        lat         lng
# 12                 0 2015-02-13 21:00:00  14.876906  120.984205
# 0                  0 2015-04-27 14:00:00  14.756140  121.037394
# 28                 0 2015-05-05 10:00:00   7.162840  125.569877
# 27                 0 2015-05-05 10:00:00   7.160072  125.572945
# 40                 0 2015-11-24 18:00:00  14.603079  120.985094
#
# [430028 rows x 4 columns]

# %% [markdown]
# ## Save as CSV

# %%
df_compiled.to_csv(FLOOD_2015_COMPILED_PATH, index=False)

# %% [markdown]
# # Convert location to city

# %% [markdown]
# ## Load compiled flood data

# %%
df = pd.read_csv(FLOOD_2015_COMPILED_PATH, skipinitialspace=True)

# Change column data type
df[COL_HEIGHT] = pd.to_numeric(df[COL_HEIGHT])
df[COL_DATETIME] = pd.to_datetime(df[COL_DATETIME])
df[COL_LAT] = pd.to_numeric(df[COL_LAT])
df[COL_LNG] = pd.to_numeric(df[COL_LNG])
df
# Out:
#         flood_height          flood_time        lat         lng
# 0                  0 2015-02-13 21:00:00  14.876906  120.984205
# 1                  0 2015-04-27 14:00:00  14.756140  121.037394
# 2                  0 2015-05-05 10:00:00   7.162840  125.569877
# 3                  0 2015-05-05 10:00:00   7.160072  125.572945
# 4                  0 2015-05-05 10:00:00   7.160125  125.572956
# 5                  0 2015-06-02 12:00:00  13.218210  121.102438
# 6                  0 2015-06-02 12:00:00  13.218043  121.102717
# 7                  0 2015-06-16 03:00:00  14.543954  121.050534
# 8                  2 2015-07-05 16:00:00  14.719798  120.969386
# 9                  2 2015-07-05 16:00:00  14.720031  120.968555
# 10                 2 2015-07-05 16:00:00  14.722080  120.969172
# 11                 1 2015-07-09 14:40:00  14.405829  120.907879
# 12                 2 2015-07-09 20:00:00  14.635925  120.982299
# 13                 0 2015-07-12 11:00:00  14.702135  120.948374
# 14                 0 2015-07-12 11:00:00  14.701716  120.948511
# 15                 0 2015-07-12 11:00:00  14.702256  120.950203
# 16                 0 2015-07-12 11:00:00  14.702402  120.949423
# 17                 1 2015-07-29 15:00:00  14.589592  121.099222
# 18                 1 2015-08-09 14:40:00  14.406341  120.905932
# 19                 0 2015-08-17 21:00:00   8.484076  124.659940
# 20                 0 2015-08-17 21:00:00   8.483200  124.654999
# 21                 2 2015-08-21 16:30:00  14.405824  120.907889
# 22                 2 2015-08-21 16:40:00  14.405613  120.908079
# 23                 2 2015-08-21 16:40:00  14.405868  120.907036
# 24                 2 2015-08-21 16:40:00  14.405728  120.907473
# 25                 2 2015-08-21 17:00:00  14.408720  120.904450
# 26                 0 2015-08-23 17:00:00  11.942860  120.036636
# 27                 2 2015-08-24 22:00:00  14.406206  120.910877
# 28                 0 2015-08-24 22:00:00  14.406460  120.910914
# 29                 3 2015-09-08 13:00:00  11.643154  122.926474
# ...              ...                 ...        ...         ...
# 429998             2 2015-10-19 07:30:00  17.611767  121.730534
# 429999             2 2015-10-19 07:30:00  17.611740  121.730534
# 430000             2 2015-10-19 07:30:00  17.611850  121.730534
# 430001             2 2015-10-19 07:30:00  17.611685  121.730534
# 430002             2 2015-10-19 07:30:00  17.611657  121.730534
# 430003             2 2015-10-19 07:30:00  17.611629  121.730534
# 430004             2 2015-10-19 07:30:00  17.611602  121.730534
# 430005             2 2015-10-19 07:30:00  17.611574  121.730534
# 430006             2 2015-10-19 07:30:00  17.611546  121.730534
# 430007             2 2015-10-19 07:30:00  17.611519  121.730534
# 430008             2 2015-10-19 07:30:00  17.611712  121.730534
# 430009             3 2015-10-19 12:00:00  17.621124  121.723459
# 430010             0 2015-10-19 15:00:00  17.343996  121.747836
# 430011             2 2015-10-19 15:00:00  17.343111  121.748506
# 430012             0 2015-10-20 12:00:00  17.342603  121.750733
# 430013             6 2015-10-22 12:00:00  14.918207  120.778311
# 430014             0 2015-11-05 02:00:00  13.946163  120.668172
# 430015             0 2015-11-05 02:00:00  13.971449  121.123388
# 430016             0 2015-11-05 02:15:00  13.946174  120.667802
# 430017             0 2015-11-24 18:00:00  14.609354  120.987030
# 430018             0 2015-11-24 18:00:00  14.600473  120.991037
# 430019             0 2015-11-24 18:00:00  14.601573  120.992754
# 430020             0 2015-11-24 18:00:00  14.600597  120.996187
# 430021             0 2015-11-24 18:00:00  14.601147  120.999384
# 430022             0 2015-11-24 18:00:00  14.602845  121.015950
# 430023             0 2015-11-24 18:00:00  14.604418  121.017355
# 430024             0 2015-11-24 18:00:00  14.617634  121.001627
# 430025             0 2015-11-24 18:00:00  14.623593  120.989128
# 430026             0 2015-11-24 18:00:00  14.609894  120.986258
# 430027             0 2015-11-24 18:00:00  14.603079  120.985094
#
# [430028 rows x 4 columns]

# %% [markdown]
# ## Convert long, lat to location

# %%
geolocator = Nominatim()

def get_location(location):
    retryCount = 0
    try:
        return geolocator.reverse(location)
    except GeocoderTimedOut:
        print("Retrying - ")
        return do_geocode(location)

# Make a copy of the dataframe
df_geo = df.copy()

# Merge latitude and longitude
# df_geo[COL_LOCATION] = df[COL_LAT].map(str) + ', ' + df[COL_LNG].map(str)
# df_geo.drop([COL_LAT, COL_LNG], inplace=True, axis=1)

df_geo[COL_LOCATION] = df_geo.apply(
    lambda row: geolocator.reverse((row[COL_LAT], row[COL_LNG])).address, axis=1)
# Out:
# ---------------------------------------------------------------------------
# SSLWantReadError                          Traceback (most recent call last)
# c:\users\gelo\anaconda3\envs\tensorflow\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#
# c:\users\gelo\anaconda3\envs\tensorflow\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# c:\users\gelo\anaconda3\envs\tensorflow\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# c:\users\gelo\anaconda3\envs\tensorflow\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#
# c:\users\gelo\anaconda3\envs\tensorflow\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# c:\users\gelo\anaconda3\envs\tensorflow\lib\http\client.py in send(self, data)
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#
# c:\users\gelo\anaconda3\envs\tensorflow\lib\http\client.py in connect(self)
#    1399             self.sock = self._context.wrap_socket(self.sock,
# -> 1400                                                   server_hostname=server_hostname)
#    1401             if not self._context.check_hostname and self._check_hostname:
#
# c:\users\gelo\anaconda3\envs\tensorflow\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     406                          server_hostname=server_hostname,
# --> 407                          _context=self, _session=session)
#     408
#
# c:\users\gelo\anaconda3\envs\tensorflow\lib\ssl.py in __init__(self, sock, keyfile, certfile, server_side, cert_reqs, ssl_version, ca_certs, do_handshake_on_connect, family, type, proto, fileno, suppress_ragged_eofs, npn_protocols, ciphers, server_hostname, _context, _session)
#     813                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 814                     self.do_handshake()
#     815
#
# c:\users\gelo\anaconda3\envs\tensorflow\lib\ssl.py in do_handshake(self, block)
#    1067                 self.settimeout(None)
# -> 1068             self._sslobj.do_handshake()
#    1069         finally:
#
# c:\users\gelo\anaconda3\envs\tensorflow\lib\ssl.py in do_handshake(self)
#     688         """Start the SSL/TLS handshake."""
# --> 689         self._sslobj.do_handshake()
#     690         if self.context.check_hostname:
#
# SSLWantReadError: The operation did not complete (read) (_ssl.c:777)
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# c:\users\gelo\anaconda3\envs\tensorflow\lib\site-packages\geopy\geocoders\base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     142         try:
# --> 143             page = requester(req, timeout=(timeout or self.timeout), **kwargs)
#     144         except Exception as error: # pylint: disable=W0703
#
# c:\users\gelo\anaconda3\envs\tensorflow\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#
# c:\users\gelo\anaconda3\envs\tensorflow\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     525
# --> 526         response = self._open(req, data)
#     527
#
# c:\users\gelo\anaconda3\envs\tensorflow\lib\urllib\request.py in _open(self, req, data)
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#
# c:\users\gelo\anaconda3\envs\tensorflow\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#
# c:\users\gelo\anaconda3\envs\tensorflow\lib\urllib\request.py in https_open(self, req)
#    1360             return self.do_open(http.client.HTTPSConnection, req,
# -> 1361                 context=self._context, check_hostname=self._check_hostname)
#    1362
#
# c:\users\gelo\anaconda3\envs\tensorflow\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1319             except OSError as err: # timeout error
# -> 1320                 raise URLError(err)
#    1321             r = h.getresponse()
#
# URLError: <urlopen error The operation did not complete (read) (_ssl.c:777)>
#
# During handling of the above exception, another exception occurred:
#
# GeocoderServiceError                      Traceback (most recent call last)
# <ipython-input-185-7f0fd920970d> in <module>()
#       9
#      10 df_geo[COL_LOCATION] = df_geo.apply(
# ---> 11     lambda row: geolocator.reverse((row[COL_LAT], row[COL_LNG])).address, axis=1)
#
# c:\users\gelo\anaconda3\envs\tensorflow\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4875                         f, axis,
#    4876                         reduce=reduce,
# -> 4877                         ignore_failures=ignore_failures)
#    4878             else:
#    4879                 return self._apply_broadcast(f, axis)
#
# c:\users\gelo\anaconda3\envs\tensorflow\lib\site-packages\pandas\core\frame.py in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4971             try:
#    4972                 for i, v in enumerate(series_gen):
# -> 4973                     results[i] = func(v)
#    4974                     keys.append(v.name)
#    4975             except Exception as e:
#
# <ipython-input-185-7f0fd920970d> in <lambda>(row)
#       9
#      10 df_geo[COL_LOCATION] = df_geo.apply(
# ---> 11     lambda row: geolocator.reverse((row[COL_LAT], row[COL_LNG])).address, axis=1)
#
# c:\users\gelo\anaconda3\envs\tensorflow\lib\site-packages\geopy\geocoders\osm.py in reverse(self, query, exactly_one, timeout, language)
#     246         logger.debug("%s.reverse: %s", self.__class__.__name__, url)
#     247         return self._parse_json(
# --> 248             self._call_geocoder(url, timeout=timeout), exactly_one
#     249         )
#     250
#
# c:\users\gelo\anaconda3\envs\tensorflow\lib\site-packages\geopy\geocoders\base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     169                 if "timed out" in message:
#     170                     raise GeocoderTimedOut('Service timed out')
# --> 171             raise GeocoderServiceError(message)
#     172
#     173         if hasattr(page, 'getcode'):
#
# GeocoderServiceError: ('The operation did not complete (read) (_ssl.c:777)', 'occurred at index 31')

# %%
df_geo[COL_LOCATION][0]
# Out:
# 'Bulacan Meadows Subdivision, Pulong Buhangin, Bulacan, Central Luzon, 3022, Philippines'
